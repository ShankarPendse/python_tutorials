# %%
import pandas as pd

# %%
df = pd.read_csv('../data/stack-overflow-developer-survey-2022/survey_results_public.csv')

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %% [markdown]
# # Lets select the records where salary is less than 50000

# %%
df['ConvertedCompYearly'] < 50000
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 73263    False
# 73264    False
# 73265    False
# 73266    False
# 73267    False
# Name: ConvertedCompYearly, Length: 73268, dtype: bool

# %%
filt = df['ConvertedCompYearly'] < 50000

# %%
filt
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 73263    False
# 73264    False
# 73265    False
# 73266    False
# 73267    False
# Name: ConvertedCompYearly, Length: 73268, dtype: bool

# %%
df[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 2               3  I am not primarily a developer, but I write co...
# 8               9                     I am a developer by profession
# 16             17                     I am a developer by profession
# 21             22                     I am a developer by profession
# 45             46                     I am a developer by profession
# ...           ...                                                ...
# 73096       73097                     I am a developer by profession
# 73097       73098                     I am a developer by profession
# 73100       73101                     I am a developer by profession
# 73114       73115                     I am a developer by profession
# 73120       73121                     I am a developer by profession
#
#                                               Employment  \
# 2                                    Employed, full-time
# ...

# %%
df.loc[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 2               3  I am not primarily a developer, but I write co...
# 8               9                     I am a developer by profession
# 16             17                     I am a developer by profession
# 21             22                     I am a developer by profession
# 45             46                     I am a developer by profession
# ...           ...                                                ...
# 73096       73097                     I am a developer by profession
# 73097       73098                     I am a developer by profession
# 73100       73101                     I am a developer by profession
# 73114       73115                     I am a developer by profession
# 73120       73121                     I am a developer by profession
#
#                                               Employment  \
# 2                                    Employed, full-time
# ...

# %%
df.loc[filt, 'ConvertedCompYearly']
# Out:
# 2        40205.0
# 8        49056.0
# 16       19224.0
# 21       34126.0
# 45        5124.0
#           ...
# 73096    35619.0
# 73097    16203.0
# 73100    43324.0
# 73114    41058.0
# 73120    35192.0
# Name: ConvertedCompYearly, Length: 13791, dtype: float64

# %%
df[filt, 'ConvertedCompYearly']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-118b0f3d3334> in <module>
# ----> 1 df[filt, 'ConvertedCompYearly']
#
# c:\python3.7.8\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\python3.7.8\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#    3082                 raise KeyError(key) from err
#
# ...

# %%
low_sal_filt = df['ConvertedCompYearly'] < 50000

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['Gender'].unique()
# Out:
# array([nan, 'Man', 'Or, in your own words:', 'Woman',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Prefer not to say',
#        'Man;Non-binary, genderqueer, or gender non-conforming',
#        'Or, in your own words:;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Woman', 'Man;Or, in your own words:',
#        'Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Or, in your own words:;Woman',
#        'Man;Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Or, in your own words:;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Or, in your own words:;Woman'], dtype=object)

# %%
gender = ['Man', 'Woman']

# %%
gender_filt = df['Gender'].isin(gender)

# %%
gender_filt
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 73263     True
# 73264     True
# 73265     True
# 73266     True
# 73267     True
# Name: Gender, Length: 73268, dtype: bool

# %% [markdown]
# # Fetch the records, where gender is either male of female (man or woman) and salary is less than 50000

# %%
filt = low_sal_filt & gender_filt

# %%
df.loc[filt, ['Gender', 'ConvertedCompYearly']]
# Out:
#       Gender  ConvertedCompYearly
# 2        Man              40205.0
# 8      Woman              49056.0
# 16       Man              19224.0
# 21       Man              34126.0
# 45       Man               5124.0
# ...      ...                  ...
# 73095    Man              38112.0
# 73096    Man              35619.0
# 73097    Man              16203.0
# 73100    Man              43324.0
# 73114    Man              41058.0
#
# [13417 rows x 2 columns]

# %%
filt = low_sal_filt & ~gender_filt

# %%
df.loc[filt, ['Gender', 'ConvertedCompYearly']]
# Out:
#                                                   Gender  ConvertedCompYearly
# 102                                    Prefer not to say              47743.0
# 485                               Or, in your own words:              24420.0
# 581    Non-binary, genderqueer, or gender non-conforming              47990.0
# 653                                    Prefer not to say              29436.0
# 756    Or, in your own words:;Non-binary, genderqueer...              37325.0
# ...                                                  ...                  ...
# 72333                                  Prefer not to say              38388.0
# 72375                                  Prefer not to say              26928.0
# 72685                         Man;Or, in your own words:               6449.0
# 73072  Woman;Non-binary, genderqueer, or gender non-c...              39000.0
# 73120                                                NaN              35192.0
#
# [374 rows x 2 columns]

# %% [markdown]
# # Lets filter the records where programming language is python

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0                                                      NaN
# 1                                    JavaScript;TypeScript
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 3                             C#;JavaScript;SQL;TypeScript
# 4              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                                ...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                        C#;Delphi;VBA
# 73267          C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: object

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df['LanguageHaveWorkedWith'].str.contains('Python', na = False)
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 73263     True
# 73264     True
# 73265     True
# 73266    False
# 73267    False
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: bool

# %%
lang_filt = df['LanguageHaveWorkedWith'].str.contains('Python', na = False)

# %%
df.loc[lang_filt]
# Out:
#        ResponseId                                         MainBranch  \
# 2               3  I am not primarily a developer, but I write co...
# 6               7                        I code primarily as a hobby
# 11             12  I am not primarily a developer, but I write co...
# 14             15                     I am a developer by profession
# 16             17                     I am a developer by profession
# ...           ...                                                ...
# 73257       73258                              I am learning to code
# 73261       73262                     I am a developer by profession
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
#
#                                               Employment  \
# 2                                    Employed, full-time
# ...

# %%
df.loc[~lang_filt]
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# 5               6  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df.loc[~lang_filt, 'LanguageHaveWorkedWith']
# Out:
# 0                                                NaN
# 1                              JavaScript;TypeScript
# 3                       C#;JavaScript;SQL;TypeScript
# 4        C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# 5                                            C++;Lua
#                             ...
# 73259                                         Elixir
# 73260                                             C#
# 73262                 Assembly;C;C++;Java;TypeScript
# 73266                                  C#;Delphi;VBA
# 73267    C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 39113, dtype: object

# %%
df.loc[~lang_filt, 'LanguageHaveWorkedWith'].str.contains('Python', na = False)
# Out:
# 0        False
# 1        False
# 3        False
# 4        False
# 5        False
#          ...
# 73259    False
# 73260    False
# 73262    False
# 73266    False
# 73267    False
# Name: LanguageHaveWorkedWith, Length: 39113, dtype: bool
