# %%
import pandas as pd

# %%
data_df = pd.read_csv("C:/Shankar/Datascience/Python/pandas/datasets/stack-overflow-developer-survey-2019/survey_results_public.csv")

# %%
schema_df = pd.read_csv("C:/Shankar/Datascience/Python/pandas/datasets/stack-overflow-developer-survey-2019/survey_results_schema.csv")

# %%
people = {
    "first": ["shankar","chetan","chetan"],
    "last" : ["pendse", "joshi","gorkal"],
    "email" : ["pshankar1306@gmail.com", "cjsh@gmail.com", "cg@gmail.com"]
}

# %%
df = pd.DataFrame(people)

# %% [markdown]
# ## applymap: apply a function to every individual element in the dataframe.
#
# ## applymap only works on dataframe, we can not use it on series object

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      7     6     22
# 1      6     5     14
# 2      6     6     12

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.applymap(str.lower)
# Out:
#      first    last                   email
# 0  shankar  pendse  pshankar1306@gmail.com
# 1   chetan   joshi          cjsh@gmail.com
# 2   chetan  gorkal            cg@gmail.com

# %%
df.applymap(str.upper)
# Out:
#      first    last                   email
# 0  SHANKAR  PENDSE  PSHANKAR1306@GMAIL.COM
# 1   CHETAN   JOSHI          CJSH@GMAIL.COM
# 2   CHETAN  GORKAL            CG@GMAIL.COM

# %%
df
# Out:
#      first    last                   email
# 0  shankar  pendse  pshankar1306@gmail.com
# 1   chetan   joshi          cjsh@gmail.com
# 2   chetan  gorkal            cg@gmail.com

# %% [markdown]
# ## map: only works on series object
#
# ## map is used for substituting each value in a series with another value

# %%
df['first'].map({'shankar':'Kevin',
                 'pendse':'woods'})
# Out:
# 0    Kevin
# 1      NaN
# 2      NaN
# Name: first, dtype: object

# %%
df
# Out:
#      first    last                   email
# 0  shankar  pendse  pshankar1306@gmail.com
# 1   chetan   joshi          cjsh@gmail.com
# 2   chetan  gorkal            cg@gmail.com

# %%
df['first'].replace({'shankar':'Kevin',
                 'pendse':'woods'})
# Out:
# 0     Kevin
# 1    chetan
# 2    chetan
# Name: first, dtype: object

# %%
df
# Out:
#      first    last                   email
# 0  shankar  pendse  pshankar1306@gmail.com
# 1   chetan   joshi          cjsh@gmail.com
# 2   chetan  gorkal            cg@gmail.com

# %%
df['first'] = df['first'].replace({'shankar':'Kevin',
                 'pendse':'woods'})

# %%
df
# Out:
#     first    last                   email
# 0   Kevin  pendse  pshankar1306@gmail.com
# 1  chetan   joshi          cjsh@gmail.com
# 2  chetan  gorkal            cg@gmail.com

# %%
data_df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
data_df.set_index('Respondent', inplace = True)

# %%
data_df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
pd.set_option("display.max_columns", 85)

# %%
data_df.rename(columns = {'ConvertedComp':'SalaryUSD'})
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
data_df.rename(columns = {'ConvertedComp':'SalaryUSD'}, inplace = True)

# %%
data_df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
data_df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
## convert yes to True and No to False

data_df['Hobbyist'].map({'Yes': True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
data_df['Hobbyist'] = data_df['Hobbyist'].map({'Yes': True, 'No':False})

# %% [markdown]
# ## if there are any other values other than yes and no, those will be replaced with NaN values
#
# ## if we do not want to have NaN values for the ones that are not specified, we can make use of replace

# %%
data_df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %% [markdown]
# # Add and Remove rows and columns from Dataframes

# %%
df
# Out:
#     first    last                   email
# 0   Kevin  pendse  pshankar1306@gmail.com
# 1  chetan   joshi          cjsh@gmail.com
# 2  chetan  gorkal            cg@gmail.com

# %%
df['last'] = df['last'].replace({'pendse':'woods'})

# %%
df['first'] + ' ' + df['last']
# Out:
# 0      Kevin woods
# 1     chetan joshi
# 2    chetan gorkal
# dtype: object

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#     first    last                   email      full_name
# 0   Kevin   woods  pshankar1306@gmail.com    Kevin woods
# 1  chetan   joshi          cjsh@gmail.com   chetan joshi
# 2  chetan  gorkal            cg@gmail.com  chetan gorkal

# %%
df.drop(columns = ['first', 'last'])
# Out:
#                     email      full_name
# 0  pshankar1306@gmail.com    Kevin woods
# 1          cjsh@gmail.com   chetan joshi
# 2            cg@gmail.com  chetan gorkal

# %%
df
# Out:
#     first    last                   email      full_name
# 0   Kevin   woods  pshankar1306@gmail.com    Kevin woods
# 1  chetan   joshi          cjsh@gmail.com   chetan joshi
# 2  chetan  gorkal            cg@gmail.com  chetan gorkal

# %%
df.drop(columns = ['first', 'last'], inplace = True)

# %%
df
# Out:
#                     email      full_name
# 0  pshankar1306@gmail.com    Kevin woods
# 1          cjsh@gmail.com   chetan joshi
# 2            cg@gmail.com  chetan gorkal

# %% [markdown]
# ## If we want to re introduce first and last columns

# %%
df['full_name'].str.split()
# Out:
# 0      [Kevin, woods]
# 1     [chetan, joshi]
# 2    [chetan, gorkal]
# Name: full_name, dtype: object

# %%
df['full_name'].str.split(' ', expand = True)
# Out:
#         0       1
# 0   Kevin   woods
# 1  chetan   joshi
# 2  chetan  gorkal

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand = True)

# %%
df
# Out:
#                     email      full_name   first    last
# 0  pshankar1306@gmail.com    Kevin woods   Kevin   woods
# 1          cjsh@gmail.com   chetan joshi  chetan   joshi
# 2            cg@gmail.com  chetan gorkal  chetan  gorkal

# %%
df.append({'first':'Tony'})
# Out:
# C:\Users\Chetana.V.P\AppData\Local\Temp\ipykernel_25044\3073062333.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first':'Tony'})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25044\3073062333.py in <module>
# ----> 1 df.append({'first':'Tony'})
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    9046         )
#    9047
# -> 9048         return self._append(other, ignore_index, verify_integrity, sort)
#    9049
#    9050     def _append(
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _append(self, other, ignore_index, verify_integrity, sort)
#    9059             if isinstance(other, dict):
#    9060                 if not ignore_index:
# ...

# %%
df.append({'first':'Athar'}, ignore_index=True)
# Out:
# C:\Users\Chetana.V.P\AppData\Local\Temp\ipykernel_25044\916322122.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first':'Athar'}, ignore_index=True)
#                     email      full_name   first    last
# 0  pshankar1306@gmail.com    Kevin woods   Kevin   woods
# 1          cjsh@gmail.com   chetan joshi  chetan   joshi
# 2            cg@gmail.com  chetan gorkal  chetan  gorkal
# 3                     NaN            NaN   Athar     NaN

# %%
df
# Out:
#                     email      full_name   first    last
# 0  pshankar1306@gmail.com    Kevin woods   Kevin   woods
# 1          cjsh@gmail.com   chetan joshi  chetan   joshi
# 2            cg@gmail.com  chetan gorkal  chetan  gorkal

# %%
people = {
    "first": ["Athar","Sanjeev"],
    "last" : ["Shaikh", "kanabargi"],
    "email" : ["ashaikh@gmail.com", "sk@gmail.com"]
}

# %%
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#      first       last              email
# 0    Athar     Shaikh  ashaikh@gmail.com
# 1  Sanjeev  kanabargi       sk@gmail.com

# %%
df
# Out:
#                     email      full_name   first    last
# 0  pshankar1306@gmail.com    Kevin woods   Kevin   woods
# 1          cjsh@gmail.com   chetan joshi  chetan   joshi
# 2            cg@gmail.com  chetan gorkal  chetan  gorkal

# %%
df.append(df2, ignore_index = True)
# Out:
# C:\Users\Chetana.V.P\AppData\Local\Temp\ipykernel_25044\1169785372.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df2, ignore_index = True)
#                     email      full_name    first       last
# 0  pshankar1306@gmail.com    Kevin woods    Kevin      woods
# 1          cjsh@gmail.com   chetan joshi   chetan      joshi
# 2            cg@gmail.com  chetan gorkal   chetan     gorkal
# 3       ashaikh@gmail.com            NaN    Athar     Shaikh
# 4            sk@gmail.com            NaN  Sanjeev  kanabargi

# %%
df
# Out:
#                     email      full_name   first    last
# 0  pshankar1306@gmail.com    Kevin woods   Kevin   woods
# 1          cjsh@gmail.com   chetan joshi  chetan   joshi
# 2            cg@gmail.com  chetan gorkal  chetan  gorkal

# %%
df = df.append(df2, ignore_index = True)
# Out:
# C:\Users\Chetana.V.P\AppData\Local\Temp\ipykernel_25044\89406493.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2, ignore_index = True)

# %%
df
# Out:
#                     email      full_name    first       last
# 0  pshankar1306@gmail.com    Kevin woods    Kevin      woods
# 1          cjsh@gmail.com   chetan joshi   chetan      joshi
# 2            cg@gmail.com  chetan gorkal   chetan     gorkal
# 3       ashaikh@gmail.com            NaN    Athar     Shaikh
# 4            sk@gmail.com            NaN  Sanjeev  kanabargi

# %%
df.drop(index = 0)
# Out:
#                email      full_name    first       last
# 1     cjsh@gmail.com   chetan joshi   chetan      joshi
# 2       cg@gmail.com  chetan gorkal   chetan     gorkal
# 3  ashaikh@gmail.com            NaN    Athar     Shaikh
# 4       sk@gmail.com            NaN  Sanjeev  kanabargi

# %%
df
# Out:
#                     email      full_name    first       last
# 0  pshankar1306@gmail.com    Kevin woods    Kevin      woods
# 1          cjsh@gmail.com   chetan joshi   chetan      joshi
# 2            cg@gmail.com  chetan gorkal   chetan     gorkal
# 3       ashaikh@gmail.com            NaN    Athar     Shaikh
# 4            sk@gmail.com            NaN  Sanjeev  kanabargi

# %%
df.drop(index = df[df['first'] == 'Kevin'].index)
# Out:
#                email      full_name    first       last
# 1     cjsh@gmail.com   chetan joshi   chetan      joshi
# 2       cg@gmail.com  chetan gorkal   chetan     gorkal
# 3  ashaikh@gmail.com            NaN    Athar     Shaikh
# 4       sk@gmail.com            NaN  Sanjeev  kanabargi

# %%
filt = (df['first'] == 'Kevin')

# %%
df.drop(index = df[filt].index)
# Out:
#                email      full_name    first       last
# 1     cjsh@gmail.com   chetan joshi   chetan      joshi
# 2       cg@gmail.com  chetan gorkal   chetan     gorkal
# 3  ashaikh@gmail.com            NaN    Athar     Shaikh
# 4       sk@gmail.com            NaN  Sanjeev  kanabargi

# %%
df
# Out:
#                     email      full_name    first       last
# 0  pshankar1306@gmail.com    Kevin woods    Kevin      woods
# 1          cjsh@gmail.com   chetan joshi   chetan      joshi
# 2            cg@gmail.com  chetan gorkal   chetan     gorkal
# 3       ashaikh@gmail.com            NaN    Athar     Shaikh
# 4            sk@gmail.com            NaN  Sanjeev  kanabargi
